# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
#Read 2020 data.

df2020 = pd.read_csv("/content/drive/MyDrive/NSQIP-PUFs/NSQIP_2020.csv", index_col = 'CaseID', encoding = 'latin1', low_memory = False)

df2020.columns = map(str.upper, df2020.columns)

# %%
#Drop the columns that are not present in other years.

df2020 = df2020.drop(columns=['EOL_WDCARE', 'BLEED_UNITS_TOT'])

# %%
#Check 2020 data shape.

df2020.shape
# Out:
# (902968, 273)

# %%
#Identify ACC with CPT codes.

df2020_acc = df2020[(df2020['CPT'] == 63081) | (df2020['CONCPT1'] == 63081) | (df2020['CONCPT2'] == 63081) | (df2020['CONCPT3'] == 63081) | (df2020['CONCPT4'] == 63081) | (df2020['CONCPT5'] == 63081) | (df2020['CONCPT6'] == 63081) | (df2020['CONCPT7'] == 63081) | (df2020['CONCPT8'] == 63081) | (df2020['CONCPT9'] == 63081) | (df2020['CONCPT10'] == 63081) | (df2020['OTHERCPT1'] == 63081) | (df2020['OTHERCPT2'] == 63081) | (df2020['OTHERCPT3'] == 63081) | (df2020['OTHERCPT4'] == 63081) | (df2020['OTHERCPT5'] == 63081) | (df2020['OTHERCPT6'] == 63081) | (df2020['OTHERCPT7'] == 63081) | (df2020['OTHERCPT8'] == 63081) | (df2020['OTHERCPT9'] == 63081) | (df2020['OTHERCPT10'] == 63081) | (df2020['CPT'] == 63082) | (df2020['CONCPT1'] == 63082) | (df2020['CONCPT2'] == 63082) | (df2020['CONCPT3'] == 63082) | (df2020['CONCPT4'] == 63082) | (df2020['CONCPT5'] == 63082) | (df2020['CONCPT6'] == 63082) | (df2020['CONCPT7'] == 63082) | (df2020['CONCPT8'] == 63082) | (df2020['CONCPT9'] == 63082) | (df2020['CONCPT10'] == 63082) | (df2020['OTHERCPT1'] == 63082) | (df2020['OTHERCPT2'] == 63082) | (df2020['OTHERCPT3'] == 63082) | (df2020['OTHERCPT4'] == 63082) | (df2020['OTHERCPT5'] == 63082) | (df2020['OTHERCPT6'] == 63082) | (df2020['OTHERCPT7'] == 63082) | (df2020['OTHERCPT8'] == 63082) | (df2020['OTHERCPT9'] == 63082) | (df2020['OTHERCPT10'] == 63082)]
print(df2020_acc.shape)
# Out:
# (543, 273)

# %%
#Read 2019 data.

df2019 = pd.read_csv("/content/drive/MyDrive/NSQIP-PUFs/NSQIP_2019.csv", index_col = 'CASEID', encoding = 'latin1', low_memory = False)

df2019.columns = map(str.upper, df2019.columns)

# %%
#Check 2019 data shape.

df2019.shape
# Out:
# (1048575, 273)

# %%
#Identify ACC with CPT codes.

df2019_acc = df2019[(df2019['CPT'] == 63081) | (df2019['CONCPT1'] == 63081) | (df2019['CONCPT2'] == 63081) | (df2019['CONCPT3'] == 63081) | (df2019['CONCPT4'] == 63081) | (df2019['CONCPT5'] == 63081) | (df2019['CONCPT6'] == 63081) | (df2019['CONCPT7'] == 63081) | (df2019['CONCPT8'] == 63081) | (df2019['CONCPT9'] == 63081) | (df2019['CONCPT10'] == 63081) | (df2019['OTHERCPT1'] == 63081) | (df2019['OTHERCPT2'] == 63081) | (df2019['OTHERCPT3'] == 63081) | (df2019['OTHERCPT4'] == 63081) | (df2019['OTHERCPT5'] == 63081) | (df2019['OTHERCPT6'] == 63081) | (df2019['OTHERCPT7'] == 63081) | (df2019['OTHERCPT8'] == 63081) | (df2019['OTHERCPT9'] == 63081) | (df2019['OTHERCPT10'] == 63081) | (df2019['CPT'] == 63082) | (df2019['CONCPT1'] == 63082) | (df2019['CONCPT2'] == 63082) | (df2019['CONCPT3'] == 63082) | (df2019['CONCPT4'] == 63082) | (df2019['CONCPT5'] == 63082) | (df2019['CONCPT6'] == 63082) | (df2019['CONCPT7'] == 63082) | (df2019['CONCPT8'] == 63082) | (df2019['CONCPT9'] == 63082) | (df2019['CONCPT10'] == 63082) | (df2019['OTHERCPT1'] == 63082) | (df2019['OTHERCPT2'] == 63082) | (df2019['OTHERCPT3'] == 63082) | (df2019['OTHERCPT4'] == 63082) | (df2019['OTHERCPT5'] == 63082) | (df2019['OTHERCPT6'] == 63082) | (df2019['OTHERCPT7'] == 63082) | (df2019['OTHERCPT8'] == 63082) | (df2019['OTHERCPT9'] == 63082) | (df2019['OTHERCPT10'] == 63082)]
print(df2019_acc.shape)
# Out:
# (681, 273)

# %%
#Read 2018 data.

df2018 = pd.read_csv("/content/drive/MyDrive/NSQIP-PUFs/NSQIP_2018.csv", index_col = 'CaseID', encoding = 'latin1', low_memory = False)

df2018.columns = map(str.upper, df2018.columns)

# %%
#Check 2018 data shape.

df2018.shape
# Out:
# (1020511, 273)

# %%
#Identify ACC with CPT codes.

df2018_acc = df2018[(df2018['CPT'] == 63081) | (df2018['CONCPT1'] == 63081) | (df2018['CONCPT2'] == 63081) | (df2018['CONCPT3'] == 63081) | (df2018['CONCPT4'] == 63081) | (df2018['CONCPT5'] == 63081) | (df2018['CONCPT6'] == 63081) | (df2018['CONCPT7'] == 63081) | (df2018['CONCPT8'] == 63081) | (df2018['CONCPT9'] == 63081) | (df2018['CONCPT10'] == 63081) | (df2018['OTHERCPT1'] == 63081) | (df2018['OTHERCPT2'] == 63081) | (df2018['OTHERCPT3'] == 63081) | (df2018['OTHERCPT4'] == 63081) | (df2018['OTHERCPT5'] == 63081) | (df2018['OTHERCPT6'] == 63081) | (df2018['OTHERCPT7'] == 63081) | (df2018['OTHERCPT8'] == 63081) | (df2018['OTHERCPT9'] == 63081) | (df2018['OTHERCPT10'] == 63081) | (df2018['CPT'] == 63082) | (df2018['CONCPT1'] == 63082) | (df2018['CONCPT2'] == 63082) | (df2018['CONCPT3'] == 63082) | (df2018['CONCPT4'] == 63082) | (df2018['CONCPT5'] == 63082) | (df2018['CONCPT6'] == 63082) | (df2018['CONCPT7'] == 63082) | (df2018['CONCPT8'] == 63082) | (df2018['CONCPT9'] == 63082) | (df2018['CONCPT10'] == 63082) | (df2018['OTHERCPT1'] == 63082) | (df2018['OTHERCPT2'] == 63082) | (df2018['OTHERCPT3'] == 63082) | (df2018['OTHERCPT4'] == 63082) | (df2018['OTHERCPT5'] == 63082) | (df2018['OTHERCPT6'] == 63082) | (df2018['OTHERCPT7'] == 63082) | (df2018['OTHERCPT8'] == 63082) | (df2018['OTHERCPT9'] == 63082) | (df2018['OTHERCPT10'] == 63082)]
print(df2018_acc.shape)
# Out:
# (689, 273)

# %%
#Read 2017 data.

df2017 = pd.read_csv("/content/drive/MyDrive/NSQIP-PUFs/NSQIP_2017.csv", index_col = 'CaseID', encoding = 'latin1', low_memory = False)

df2017.columns = map(str.upper, df2017.columns)

# %%
#Check 2017 data shape.

df2017.shape
# Out:
# (1028713, 273)

# %%
#Identify ACC with CPT codes.

df2017_acc = df2017[(df2017['CPT'] == 63081) | (df2017['CONCPT1'] == 63081) | (df2017['CONCPT2'] == 63081) | (df2017['CONCPT3'] == 63081) | (df2017['CONCPT4'] == 63081) | (df2017['CONCPT5'] == 63081) | (df2017['CONCPT6'] == 63081) | (df2017['CONCPT7'] == 63081) | (df2017['CONCPT8'] == 63081) | (df2017['CONCPT9'] == 63081) | (df2017['CONCPT10'] == 63081) | (df2017['OTHERCPT1'] == 63081) | (df2017['OTHERCPT2'] == 63081) | (df2017['OTHERCPT3'] == 63081) | (df2017['OTHERCPT4'] == 63081) | (df2017['OTHERCPT5'] == 63081) | (df2017['OTHERCPT6'] == 63081) | (df2017['OTHERCPT7'] == 63081) | (df2017['OTHERCPT8'] == 63081) | (df2017['OTHERCPT9'] == 63081) | (df2017['OTHERCPT10'] == 63081) | (df2017['CPT'] == 63082) | (df2017['CONCPT1'] == 63082) | (df2017['CONCPT2'] == 63082) | (df2017['CONCPT3'] == 63082) | (df2017['CONCPT4'] == 63082) | (df2017['CONCPT5'] == 63082) | (df2017['CONCPT6'] == 63082) | (df2017['CONCPT7'] == 63082) | (df2017['CONCPT8'] == 63082) | (df2017['CONCPT9'] == 63082) | (df2017['CONCPT10'] == 63082) | (df2017['OTHERCPT1'] == 63082) | (df2017['OTHERCPT2'] == 63082) | (df2017['OTHERCPT3'] == 63082) | (df2017['OTHERCPT4'] == 63082) | (df2017['OTHERCPT5'] == 63082) | (df2017['OTHERCPT6'] == 63082) | (df2017['OTHERCPT7'] == 63082) | (df2017['OTHERCPT8'] == 63082) | (df2017['OTHERCPT9'] == 63082) | (df2017['OTHERCPT10'] == 63082)]
print(df2017_acc.shape)
# Out:
# (737, 273)

# %%
#Read 2016 data.

df2016 = pd.read_csv("/content/drive/MyDrive/NSQIP-PUFs/NSQIP_2016.csv", index_col = 'CaseID', encoding = 'latin1', low_memory = False)

df2016.columns = map(str.upper, df2016.columns)

# %%
#Check 2016 data shape.

df2016.shape
# Out:
# (1000393, 273)

# %%
#Identify ACC with CPT codes.

df2016_acc = df2016[(df2016['CPT'] == 63081) | (df2016['CONCPT1'] == 63081) | (df2016['CONCPT2'] == 63081) | (df2016['CONCPT3'] == 63081) | (df2016['CONCPT4'] == 63081) | (df2016['CONCPT5'] == 63081) | (df2016['CONCPT6'] == 63081) | (df2016['CONCPT7'] == 63081) | (df2016['CONCPT8'] == 63081) | (df2016['CONCPT9'] == 63081) | (df2016['CONCPT10'] == 63081) | (df2016['OTHERCPT1'] == 63081) | (df2016['OTHERCPT2'] == 63081) | (df2016['OTHERCPT3'] == 63081) | (df2016['OTHERCPT4'] == 63081) | (df2016['OTHERCPT5'] == 63081) | (df2016['OTHERCPT6'] == 63081) | (df2016['OTHERCPT7'] == 63081) | (df2016['OTHERCPT8'] == 63081) | (df2016['OTHERCPT9'] == 63081) | (df2016['OTHERCPT10'] == 63081) | (df2016['CPT'] == 63082) | (df2016['CONCPT1'] == 63082) | (df2016['CONCPT2'] == 63082) | (df2016['CONCPT3'] == 63082) | (df2016['CONCPT4'] == 63082) | (df2016['CONCPT5'] == 63082) | (df2016['CONCPT6'] == 63082) | (df2016['CONCPT7'] == 63082) | (df2016['CONCPT8'] == 63082) | (df2016['CONCPT9'] == 63082) | (df2016['CONCPT10'] == 63082) | (df2016['OTHERCPT1'] == 63082) | (df2016['OTHERCPT2'] == 63082) | (df2016['OTHERCPT3'] == 63082) | (df2016['OTHERCPT4'] == 63082) | (df2016['OTHERCPT5'] == 63082) | (df2016['OTHERCPT6'] == 63082) | (df2016['OTHERCPT7'] == 63082) | (df2016['OTHERCPT8'] == 63082) | (df2016['OTHERCPT9'] == 63082) | (df2016['OTHERCPT10'] == 63082)]
print(df2016_acc.shape)
# Out:
# (874, 273)

# %%
#Read 2015 data.

df2015 = pd.read_csv("/content/drive/MyDrive/NSQIP-PUFs/NSQIP_2015.csv", index_col = 'CaseID', encoding = 'latin1', low_memory = False)

df2015.columns = map(str.upper, df2015.columns)

# %%
#Check 2015 data shape.

df2015.shape
# Out:
# (1020511, 273)

# %%
#Identify ACC with CPT codes.

df2015_acc = df2015[(df2015['CPT'] == 63081) | (df2015['CONCPT1'] == 63081) | (df2015['CONCPT2'] == 63081) | (df2015['CONCPT3'] == 63081) | (df2015['CONCPT4'] == 63081) | (df2015['CONCPT5'] == 63081) | (df2015['CONCPT6'] == 63081) | (df2015['CONCPT7'] == 63081) | (df2015['CONCPT8'] == 63081) | (df2015['CONCPT9'] == 63081) | (df2015['CONCPT10'] == 63081) | (df2015['OTHERCPT1'] == 63081) | (df2015['OTHERCPT2'] == 63081) | (df2015['OTHERCPT3'] == 63081) | (df2015['OTHERCPT4'] == 63081) | (df2015['OTHERCPT5'] == 63081) | (df2015['OTHERCPT6'] == 63081) | (df2015['OTHERCPT7'] == 63081) | (df2015['OTHERCPT8'] == 63081) | (df2015['OTHERCPT9'] == 63081) | (df2015['OTHERCPT10'] == 63081) | (df2015['CPT'] == 63082) | (df2015['CONCPT1'] == 63082) | (df2015['CONCPT2'] == 63082) | (df2015['CONCPT3'] == 63082) | (df2015['CONCPT4'] == 63082) | (df2015['CONCPT5'] == 63082) | (df2015['CONCPT6'] == 63082) | (df2015['CONCPT7'] == 63082) | (df2015['CONCPT8'] == 63082) | (df2015['CONCPT9'] == 63082) | (df2015['CONCPT10'] == 63082) | (df2015['OTHERCPT1'] == 63082) | (df2015['OTHERCPT2'] == 63082) | (df2015['OTHERCPT3'] == 63082) | (df2015['OTHERCPT4'] == 63082) | (df2015['OTHERCPT5'] == 63082) | (df2015['OTHERCPT6'] == 63082) | (df2015['OTHERCPT7'] == 63082) | (df2015['OTHERCPT8'] == 63082) | (df2015['OTHERCPT9'] == 63082) | (df2015['OTHERCPT10'] == 63082)]
print(df2015_acc.shape)
# Out:
# (689, 273)

# %%
#Read 2014 data.

df2014 = pd.read_csv("/content/drive/MyDrive/NSQIP-PUFs/NSQIP_2014.csv", index_col = 'CaseID', encoding = 'latin1', low_memory = False)

df2014.columns = map(str.upper, df2014.columns)

# %%
#Check 2014 data shape.

df2014.shape
# Out:
# (1028713, 273)

# %%
#Identify ACC with CPT codes.

df2014_acc = df2014[(df2014['CPT'] == 63081) | (df2014['CONCPT1'] == 63081) | (df2014['CONCPT2'] == 63081) | (df2014['CONCPT3'] == 63081) | (df2014['CONCPT4'] == 63081) | (df2014['CONCPT5'] == 63081) | (df2014['CONCPT6'] == 63081) | (df2014['CONCPT7'] == 63081) | (df2014['CONCPT8'] == 63081) | (df2014['CONCPT9'] == 63081) | (df2014['CONCPT10'] == 63081) | (df2014['OTHERCPT1'] == 63081) | (df2014['OTHERCPT2'] == 63081) | (df2014['OTHERCPT3'] == 63081) | (df2014['OTHERCPT4'] == 63081) | (df2014['OTHERCPT5'] == 63081) | (df2014['OTHERCPT6'] == 63081) | (df2014['OTHERCPT7'] == 63081) | (df2014['OTHERCPT8'] == 63081) | (df2014['OTHERCPT9'] == 63081) | (df2014['OTHERCPT10'] == 63081) | (df2014['CPT'] == 63082) | (df2014['CONCPT1'] == 63082) | (df2014['CONCPT2'] == 63082) | (df2014['CONCPT3'] == 63082) | (df2014['CONCPT4'] == 63082) | (df2014['CONCPT5'] == 63082) | (df2014['CONCPT6'] == 63082) | (df2014['CONCPT7'] == 63082) | (df2014['CONCPT8'] == 63082) | (df2014['CONCPT9'] == 63082) | (df2014['CONCPT10'] == 63082) | (df2014['OTHERCPT1'] == 63082) | (df2014['OTHERCPT2'] == 63082) | (df2014['OTHERCPT3'] == 63082) | (df2014['OTHERCPT4'] == 63082) | (df2014['OTHERCPT5'] == 63082) | (df2014['OTHERCPT6'] == 63082) | (df2014['OTHERCPT7'] == 63082) | (df2014['OTHERCPT8'] == 63082) | (df2014['OTHERCPT9'] == 63082) | (df2014['OTHERCPT10'] == 63082)]
print(df2014_acc.shape)
# Out:
# (737, 273)

# %%
#Combine data.

dfs = [df2014_acc, df2015_acc, df2016_acc, df2017_acc, df2018_acc, df2019_acc, df2020_acc]

combined = pd.concat(dfs)

# %%
#Check data shape.

combined.shape
# Out:
# (4950, 273)

# %%
#See combined dataframe head.

combined.head()
# Out:
#          PUFYEAR     SEX RACE_NEW ETHNICITY_HISPANIC  \
# 6850148     2017    male    White                 No
# 6693543     2017    male    White                 No
# 6721908     2017  female    White                 No
# 7439613     2017  female    White                 No
# 7517084     2017    male    White                 No
#
#                                                 PRNCPTX    CPT  WORKRVU  \
# 6850148  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 6693543  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 6721908  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 7439613  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 7517084  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
#
#              INOUT                                TRANST AGE  ...  \
# 6850148  Inpatient  Not transferred (admitted from home)  74  ...
# 6693543  Inpatient  Not transferred (admitted from home)  43  ...
# ...

# %%
#See combined dataframe tail.

combined.tail()
# Out:
#           PUFYEAR     SEX              RACE_NEW ETHNICITY_HISPANIC  \
# 10874376     2020    male                 White                 No
# 11193408     2020    male                 White                 No
# 11193856     2020  female                 White                 No
# 10442391     2020    male  Unknown/Not Reported                Yes
# 11180561     2020    male  Unknown/Not Reported                Yes
#
#                                                  PRNCPTX    CPT  WORKRVU  \
# 10874376  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 11193408  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 11193856  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 10442391  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
# 11180561  VERTEBRAL CORPECTOMY ANT DCMPRN CERVICAL 1 SEG  63081     26.1
#
#                INOUT                                TRANST AGE  ...  \
# ...

# %%
#Save combined data.

combined.to_csv('/content/drive/MyDrive/NSQIP-ACC/acc_combined.csv')
